# %%
import pandas as pd

# %%
df = pd.read_csv('D:\CoL\colsom00.txt',sep="|",header=None)
# Out:
# C:\Users\siegl\AppData\Local\Temp\ipykernel_10972\3907306101.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:\CoL\colsom00.txt',sep="|",header=None)

# %%
df.columns=['Year','State.Code','State.Abbr','County.Code','County.Name','Commodity.Code','Commodity.Name', \
                   'Insurance.Plan.Code','Insurance.Plan.Abbr','Coverage.Category','Stage.Code','Damage.Cause.Code', \
                   'Damage.Causes.Descr','Month.Of.Loss','Month.Of.Loss.Name','Year.Of.Loss','Policies.Earning.Premium', \
                   'Policies.Indemnified','Net.Planted.Acres','Net.Endorsed.Acres', 'Liability','Total.Premium','Producer.Paid.Premium',\
                  'Subsidy','State/Provate.Subsidy','Additional.Subsidy','EFA.Premium.Discount','Determined.Acres','Indemnity.Amount','Loss.Ratio']

# %%
df.head()
# Out:
#    Year  State.Code State.Abbr  County.Code                     County.Name  \
# 0  2000           1         AL            1  Autauga
# 1  2000           1         AL            1  Autauga
# 2  2000           1         AL            1  Autauga
# 3  2000           1         AL            1  Autauga
# 4  2000           1         AL            1  Autauga
#
#    Commodity.Code                  Commodity.Name  Insurance.Plan.Code  \
# 0              11  WHEAT                                            90
# 1              11  WHEAT                                            90
# 2              11  WHEAT                                            90
# 3              11  WHEAT                                            90
# 4              21  COTTON                                           44
#
#    Insurance.Plan.Abbr Coverage.Category  ... Liability  Total.Premium  \
# 0                  NaN                 A  ...    909.60          146.0
# ...

# %%
filenames = ['colsom90','colsom91','colsom92','colsom93','colsom94','colsom95','colsom96','colsom97','colsom98','colsom99', \
             'colsom00','colsom01','colsom02','colsom03','colsom04','colsom05','colsom06','colsom07','colsom08','colsom09','colsom10',\
             'colsom11','colsom12','colsom13','colsom14','colsom15','colsom_2016','colsom_2017','colsom_2018','colsom_2019','colsom_2020',\
             'colsom_2021','colsom_2022']
df = pd.read_csv('D:\CoL\colsom89.txt',sep="|",header=None)
colnames=['Year','State.Code','State.Abbr','County.Code','County.Name','Commodity.Code','Commodity.Name', \
                   'Insurance.Plan.Code','Insurance.Plan.Abbr','Coverage.Category','Stage.Code','Damage.Cause.Code', \
                   'Damage.Causes.Descr','Month.Of.Loss','Month.Of.Loss.Name','Year.Of.Loss','Policies.Earning.Premium', \
                   'Policies.Indemnified','Net.Planted.Acres','Net.Endorsed.Acres', 'Liability','Total.Premium','Producer.Paid.Premium',\
                  'Subsidy','State/Provate.Subsidy','Additional.Subsidy','EFA.Premium.Discount','Determined.Acres','Indemnity.Amount','Loss.Ratio']

# %%
name = "D:/CoL/" + filenames[1] + ".txt"
print(name)
# Out:
# D:/CoL/colsom91.txt

# %%
x = len(filenames)-1
for i in range(0,x):
    name = 'D:/CoL/' + filenames[i] + '.txt'
    temp = pd.read_csv(name,sep="|",header=None)
    df=pd.concat([df,temp])
df.columns=colnames

# %%
df.tail()
# Out:
#         Year  State.Code State.Abbr  County.Code  \
# 133448  2022          56         WY           45
# 133449  2022          56         WY           45
# 133450  2022          56         WY           45
# 133451  2022          56         WY           45
# 133452  2022          56         WY          999
#
#                            County.Name  Commodity.Code  \
# 133448  Weston                                    9999
# 133449  Weston                                    9999
# 133450  Weston                                    9999
# 133451  Weston                                    9999
# 133452  All Other Counties                        9999
#
#                         Commodity.Name  Insurance.Plan.Code  \
# 133448  All Other Crops                                  90
# 133449  All Other Crops                                  13
# 133450  All Other Crops                                  13
# 133451  All Other Crops                                  13
# ...

# %%
df.to_csv('D:/CoL/MainCoL.csv')
