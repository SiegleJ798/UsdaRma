# %%
import pandas as pd
filenames = ['sobcov90','sobcov91','sobcov92','sobcov93','sobcov94','sobcov95','sobcov96','sobcov97','sobcov98','sobcov99', \
             'sobcov00','sobcov01','sobcov02','sobcov03','sobcov04','sobcov05','sobcov06','sobcov07','sobcov08','sobcov09','sobcov10',\
             'sobcov11','sobcov12','sobcov13','sobcov14','sobcov15','sobcov_2016','sobcov_2017','sobcov_2018','sobcov_2019','sobcov_2020',\
             'sobcov_2021','sobcov_2022']
df = pd.read_csv('D:\SoB\sobcov89.txt',sep="|",header=None)

colnames=['Year','State.Code','State.Abbr','County.Code','County.Name','Commodity.Code','Commodity.Name', \
                   'Insurance.Plan.Code','Insurance.Plan.Abbr','Coverage.Category','Delivery.Type','Coverage.Level','Policies.Sold.Count','Policies.Earning.Premium', \
                   'Policies.Indemnified','Units.Earning.Premium','Units.Indemnified','Quantity.Type','Net.Planted.Quantity','Net.Endorsed.Acres', 'Liability','Total.Premium',\
                  'Subsidy','State/Provate.Subsidy','Additional.Subsidy','EFA.Premium.Discount','Indemnity.Amount','Loss.Ratio']             
df.head()
# Out:
#      0   1   2    3                               4     5   \
# 0  1989   1  AL    0  All Other Counties              9999
# 1  1989   1  AL  999  All Other Counties              9999
# 2  1989   1  AL  999  All Other Counties              9999
# 3  1989   1  AL  999  All Other Counties              9999
# 4  1989   1  AL  999  All Other Counties              9999
#
#                                6   7           8      9   ...    18  19  \
# 0  All Other Crops                 90  APH         E      ...     0   0
# 1  All Other Crops                 90  APH         E      ...     0   0
# 2  All Other Crops                 90  APH         E      ...  1147   0
# 3  All Other Crops                 90  APH         E      ...   413   0
# 4  All Other Crops                 90  APH         E      ...   180   0
#
#        20     21    22  23  24 25     26    27
# 0       0      0     0   0   0  0      0  0.00
# 1       0      0     0   0   0  0      0  0.00
# 2  206577  13216  3988   0   0  0  36662  2.77
# 3   95934   8352  2473   0   0  0   3720  0.45
# 4    7207   1892   319   0   0  0   4983  2.63
#
# [5 rows x 28 columns]

# %%
x = len(filenames)-1
for i in range(0,x):
    name = 'D:/SoB/' + filenames[x] + '.txt'
    temp = pd.read_csv(name,sep="|",header=None)
    df=pd.concat([df,temp])
df.columns=colnames

# %%
df.tail()
# Out:
#         Year  State.Code State.Abbr  County.Code  \
# 149933  2022          56         WY           45
# 149934  2022          56         WY           45
# 149935  2022          56         WY           45
# 149936  2022          56         WY           45
# 149937  2022          56         WY           45
#
#                            County.Name  Commodity.Code  \
# 149933  Weston                                    9999
# 149934  Weston                                    9999
# 149935  Weston                                    9999
# 149936  Weston                                    9999
# 149937  Weston                                    9999
#
#                         Commodity.Name  Insurance.Plan.Code  \
# 149933  All Other Crops                                  13
# 149934  All Other Crops                                  13
# 149935  All Other Crops                                   2
# 149936  All Other Crops                                   1
# 149937  All Other Crops                                   1
#
#        Insurance.Plan.Abbr Coverage.Category  ... Net.Planted.Quantity  \
# 149933          RI                     A      ...               2091.0
# 149934          RI                     A      ...              10011.0
# 149935          RP                     A      ...                  0.0
# 149936          YP                     A      ...                 97.0
# 149937          YP                     A      ...                133.0
#
#         Net.Endorsed.Acres  Liability  Total.Premium  Subsidy  \
# 149933                   0    38256.0         6504.0     3579
# 149934                   0    82771.0        13466.0     6868
# 149935                   0        0.0            0.0        0
# 149936                   0     9190.0         1512.0      893
# 149937                   0    13812.0         3184.0     1752
#
#         State/Provate.Subsidy  Additional.Subsidy EFA.Premium.Discount  \
# 149933                      0                   0                    0
# 149934                      0                   0                    0
# 149935                      0                   0                    0
# 149936                      0                   0                    0
# 149937                      0                   0                    0
#
#         Indemnity.Amount  Loss.Ratio
# 149933                 0        0.00
# 149934              9387        0.70
# 149935                 0        0.00
# 149936                 0        0.00
# 149937              4033        1.27
#
# [5 rows x 28 columns]

# %%
df.to_csv('D:/SoB/MainSoB.csv')
